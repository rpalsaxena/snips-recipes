# %%
# import libraries

import numpy as np
import matplotlib.pyplot as plt

# %%
# define a set of points to evaluate
x = np.linspace(-0.0001, 1, 200)
x
# Out:
# array([-1.00000000e-04,  4.92562814e-03,  9.95125628e-03,  1.49768844e-02,
#         2.00025126e-02,  2.50281407e-02,  3.00537688e-02,  3.50793970e-02,
#         4.01050251e-02,  4.51306533e-02,  5.01562814e-02,  5.51819095e-02,
#         6.02075377e-02,  6.52331658e-02,  7.02587940e-02,  7.52844221e-02,
#         8.03100503e-02,  8.53356784e-02,  9.03613065e-02,  9.53869347e-02,
#         1.00412563e-01,  1.05438191e-01,  1.10463819e-01,  1.15489447e-01,
#         1.20515075e-01,  1.25540704e-01,  1.30566332e-01,  1.35591960e-01,
#         1.40617588e-01,  1.45643216e-01,  1.50668844e-01,  1.55694472e-01,
#         1.60720101e-01,  1.65745729e-01,  1.70771357e-01,  1.75796985e-01,
#         1.80822613e-01,  1.85848241e-01,  1.90873869e-01,  1.95899497e-01,
#         2.00925126e-01,  2.05950754e-01,  2.10976382e-01,  2.16002010e-01,
#         2.21027638e-01,  2.26053266e-01,  2.31078894e-01,  2.36104523e-01,
#         2.41130151e-01,  2.46155779e-01,  2.51181407e-01,  2.56207035e-01,
#         2.61232663e-01,  2.66258291e-01,  2.71283920e-01,  2.76309548e-01,
#         2.81335176e-01,  2.86360804e-01,  2.91386432e-01,  2.96412060e-01,
#         3.01437688e-01,  3.06463317e-01,  3.11488945e-01,  3.16514573e-01,
#         3.21540201e-01,  3.26565829e-01,  3.31591457e-01,  3.36617085e-01,
#         3.41642714e-01,  3.46668342e-01,  3.51693970e-01,  3.56719598e-01,
#         3.61745226e-01,  3.66770854e-01,  3.71796482e-01,  3.76822111e-01,
#         3.81847739e-01,  3.86873367e-01,  3.91898995e-01,  3.96924623e-01,
#         4.01950251e-01,  4.06975879e-01,  4.12001508e-01,  4.17027136e-01,
#         4.22052764e-01,  4.27078392e-01,  4.32104020e-01,  4.37129648e-01,
#         4.42155276e-01,  4.47180905e-01,  4.52206533e-01,  4.57232161e-01,
#         4.62257789e-01,  4.67283417e-01,  4.72309045e-01,  4.77334673e-01,
#         4.82360302e-01,  4.87385930e-01,  4.92411558e-01,  4.97437186e-01,
#         5.02462814e-01,  5.07488442e-01,  5.12514070e-01,  5.17539698e-01,
#         5.22565327e-01,  5.27590955e-01,  5.32616583e-01,  5.37642211e-01,
#         5.42667839e-01,  5.47693467e-01,  5.52719095e-01,  5.57744724e-01,
#         5.62770352e-01,  5.67795980e-01,  5.72821608e-01,  5.77847236e-01,
#         5.82872864e-01,  5.87898492e-01,  5.92924121e-01,  5.97949749e-01,
#         6.02975377e-01,  6.08001005e-01,  6.13026633e-01,  6.18052261e-01,
#         6.23077889e-01,  6.28103518e-01,  6.33129146e-01,  6.38154774e-01,
#         6.43180402e-01,  6.48206030e-01,  6.53231658e-01,  6.58257286e-01,
#         6.63282915e-01,  6.68308543e-01,  6.73334171e-01,  6.78359799e-01,
#         6.83385427e-01,  6.88411055e-01,  6.93436683e-01,  6.98462312e-01,
#         7.03487940e-01,  7.08513568e-01,  7.13539196e-01,  7.18564824e-01,
#         7.23590452e-01,  7.28616080e-01,  7.33641709e-01,  7.38667337e-01,
#         7.43692965e-01,  7.48718593e-01,  7.53744221e-01,  7.58769849e-01,
#         7.63795477e-01,  7.68821106e-01,  7.73846734e-01,  7.78872362e-01,
#         7.83897990e-01,  7.88923618e-01,  7.93949246e-01,  7.98974874e-01,
#         8.04000503e-01,  8.09026131e-01,  8.14051759e-01,  8.19077387e-01,
#         8.24103015e-01,  8.29128643e-01,  8.34154271e-01,  8.39179899e-01,
#         8.44205528e-01,  8.49231156e-01,  8.54256784e-01,  8.59282412e-01,
#         8.64308040e-01,  8.69333668e-01,  8.74359296e-01,  8.79384925e-01,
#         8.84410553e-01,  8.89436181e-01,  8.94461809e-01,  8.99487437e-01,
#         9.04513065e-01,  9.09538693e-01,  9.14564322e-01,  9.19589950e-01,
#         9.24615578e-01,  9.29641206e-01,  9.34666834e-01,  9.39692462e-01,
#         9.44718090e-01,  9.49743719e-01,  9.54769347e-01,  9.59794975e-01,
#         9.64820603e-01,  9.69846231e-01,  9.74871859e-01,  9.79897487e-01,
#         9.84923116e-01,  9.89948744e-01,  9.94974372e-01,  1.00000000e+00])

# %%
# Compute the log of x
logx = np.log(x)
# logx
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2740\682043685.py:2: RuntimeWarning: invalid value encountered in log
#   logx = np.log(x)

# %%
plt.plot(x, logx, 'ks-', markerfacecolor='w')

# %%
# plot
fig = plt.figure(figsize=(10,4))

# increase font size. FYI
plt.rcParams.update({'font.size':  15})

plt.plot(x, logx, 'ks-', markerfacecolor='w')
plt.xlabel('x')
plt.ylabel('log(x)')
plt.show()

# %%
# demonstration that log and exp are inverses

# redefine with fewer points
x = np.linspace(.0001,1,20)

# log and exp
logx = np.log(x)
expx = np.exp(x)

# the plot
plt.plot(x,x,color=[.8,.8,.8])
plt.plot(x,np.exp(logx),'o',markersize=8)
plt.plot(x,np.log(expx),'.',markersize=8)
plt.xlabel('x')
plt.ylabel('f(g(x))')
plt.legend(['unity','exp(log(x))','log(exp(x))'])
plt.show()
